# %% [markdown]
# <a href="https://colab.research.google.com/github/mokshagna78/RAG_Based-Customer-Support/blob/main/RAG_Based_Customer_Support/rag_customer_support.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # RAG-Based Customer Support Assistant

# %%
# %pip install langchain
# %pip install langchain-community
# %pip install langchain-text-splitters
# %pip install langchain-huggingface
# %pip install langgraph
# %pip install chromadb
# %pip install pypdf
# %pip install sentence-transformers
# %pip install transformers
# %pip install ollama
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 105.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 78.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 4.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 86.9 MB/s eta 0:00:00
# ...

# %%
import ollama

print("Ollama imported successfully")
# Out:
# Ollama imported successfully

# %%
import sys
print(sys.executable)
# Out:
# /usr/bin/python3

# %%
import sys
import os

# Add project root to path
sys.path.append(os.getcwd())

# %%
import os
import shutil

from modules.loader import load_pdf
from modules.chunker import chunk_documents
from modules.embedder import get_embedding_model
from modules.vector_store import create_vector_store
from modules.retriever import get_retriever
from modules.generator import get_llm, generate_answer
from modules.graph import build_graph
from modules.router import route

# %%
def list_pdfs():
    files = os.listdir("data")
    pdfs = [f for f in files if f.endswith(".pdf")]

    print("📂 Available PDFs:\n")
    for i, pdf in enumerate(pdfs):
        print(f"{i+1}. {pdf}")

    return pdfs

pdfs = list_pdfs()
# Out:
# 📂 Available PDFs:
#
# 1. knowledge.pdf

# %%
choice = int(input("\nEnter PDF number: ")) - 1
selected_file = f"data/{pdfs[choice]}"

print(f"\n✅ Selected File: {selected_file}")
# Out:
# Enter PDF number: 1
#
# ✅ Selected File: data/knowledge.pdf

# %%
docs = load_pdf(selected_file)

print("✅ PDF Loaded")
print("Pages:", len(docs))
# Out:
# ✅ PDF Loaded
# Pages: 8

# %%
chunks = chunk_documents(docs)

print("✅ Chunking Done")
print("Total Chunks:", len(chunks))
# Out:
# ✅ Chunking Done
# Total Chunks: 15

# %%
# Clear old DB
if os.path.exists("chroma_db"):
    shutil.rmtree("chroma_db")

embedding_model = get_embedding_model()
db = create_vector_store(chunks, embedding_model)

print("✅ Vector DB Created")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# ✅ Vector DB Created
# ...

# %%
retriever = get_retriever(db)

print("✅ Retriever Ready")
# Out:
# ✅ Retriever Ready

# %%
llm = get_llm()

print("✅ LLM Ready (Llama3)")
# Out:
# ✅ LLM Ready (Llama3)

# %%
app = build_graph(llm, retriever)

print("✅ LangGraph Workflow Ready")
# Out:
# ✅ LangGraph Workflow Ready

# %%
# !apt-get update -y
# !apt-get install zstd -y
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# zstd is already the newest version (1.4.8+dfsg-3build1).
# ...

# %%
# 1. Install required extraction dependencies
# !apt-get update -y && apt-get install zstd -y

# 2. Install Ollama
# !curl -fsSL https://ollama.com/install.sh | sh

# 3. Start the Ollama server in the background
# !nohup ollama serve > ollama.log 2>&1 &

# 4. Give the server 5 seconds to boot up
# !sleep 5

# 5. Download the model
# !ollama pull tinyllama
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# zstd is already the newest version (1.4.8+dfsg-3build1).
# ...

# %%
query = "What documents have to be submitted with the application?"

result = app.invoke({"query": query})

print("🧑 User Query:", query)
print("\n🤖 Bot Response:\n")
print(result["output"])
# Out:
# 🧑 User Query: What documents have to be submitted with the application?
#
# 🤖 Bot Response:
#
# Yes, the following documents have to be submitted along with the application for registration as an OCI in the country where the applicant is ordinarily resident:
#
# 1. Original passport (with signature) and visa if applicable (if the applicant holds a valid Indian visa). If not holding a visa or the passport has already expired, then the letter of acceptance from the Indian Mission/Post should be included.
#
# 2. Evidence for loss of certificate in case of mutilaated/damaged certificate and duplicate application (if applicable) with a fee of US $14,230/- or Rs.1,290/- paid by way of Demand Draft.
#
# ...

# %%
docs = retriever.invoke(query)

for i, doc in enumerate(docs[:3]):
    print(f"\n--- Retrieved Chunk {i+1} ---\n")
    print(doc.page_content[:300])
# Out:
# --- Retrieved Chunk 1 ---
#
# 6.  In what form should a person  apply for an OCI and where are the
# forms available?
#
# A family consisting of spouses and upto two minor children can apply
# in the same form i.e. Form XIX, which can be filed online or downloaded
# from our website www.mha.nic.in.
#
# 7.  Can application form be fil
#
# --- Retrieved Chunk 2 ---
#
# in local currency for each PIO card holder).  In case of
# application filled in India, fee Rs.14,230/- for general category
# and for PIO card holders Rs.1,290/- to be paid by way of
# Demand Draft.
#
# 5.  PIO card holders should submit a copy of his/her PIO card.
#
# 9.  What documents would qualify f
#
# --- Retrieved Chunk 3 ---
#
# 12.  Whether the applicant (s) have to take oath before the Counsel of
# the Indian Mission/Post?
#
# No. Earlier provision in this regard has been done away with.
#
# 13.  Where to submit the application?
#
# To the Indian Mission/ Post of the country of citizenship of the
# ...

# %%
decision = route(query, docs, result["output"])

print("Routing Decision:", decision)
# Out:
# Routing Decision: answer

# %%
while True:
    try:
        query = input("\nYou: ")

        if query.lower() in ["exit", "quit"]:
            print("👋 Exiting chatbot")
            break

        result = app.invoke({"query": query})
        print("\nBot:", result["output"])

    except KeyboardInterrupt:
        print("\n👋 Chat stopped manually")
        break
# Out:
# You: hello
#
# Bot: 1.  Yes, the applicants who have applied on the earlier prescribed application form can apply for an OCI without seeking fresh applications and fee in the new form. All such family combinations consisting of spouses and up to two minor children can file an application using the online or downloadable version of Form XIX available on MHA's website www.mha.nic.in. 2. Part A of the application form can be filled up online, while Part B has to be printed and submitted in block letters by hand or downloaded and printed. Printed Part A and Part B have to be submitted to the Indian Mission/Post/Office for each applicant.
#
# You: who is eligible to apply
#
# ...
